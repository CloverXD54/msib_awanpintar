# %%
message = input("ketikalah  sesuatu: ")
print(message)
# Out:
# ketikalah  sesuatu: destiyanaputri
# destiyanaputri

# %%
syarat = input(" Berapakah jumhlag syarat yang sudah anda penuhi? ")
syarat = int(syarat)
if syarat >= 5:
  print("\n Anda Dapat melanjutkan ke stage berikutnya! ")
else:
  print("\n Anda Tidak Dapat melanjutkan ke stage berikutnya! ")
# Out:
#  Berapakah jumhlag syarat yang sudah anda penuhi? 8
#
#  Anda Dapat melanjutkan ke stage berikutnya!

# %%
number = input("ketiklah satu angka, kami akan memberi keterangan ganjil atau genap: ")
number = int(number)
if number % 2 == 0:
  print(f"\nAngka {number} yang anda ketik adalah genap.")
else:
  print(f"\nAngka {number} yang anda ketik adalah ganjil.")
# Out:
# ketiklah satu angka, kami akan memberi keterangan ganjil atau genap: 5
#
# Angka 5 yang anda ketik adalah ganjil.

# %%
## Latihan INput keyboard
number = input("Berapa banyak orang dalam kelompok makan malam? ")
number = int(number)
if number >= 8:
  print(f"\nJumlah Kelompok anda {number} Orang , Anda harus menunggu list karena Table untuk {number} Orang sedang overbooked ")
else:
  print(f"\nJumlah Kelompok anda {number} , Anda dipersilahkan langsung menuju Waitreess ")
